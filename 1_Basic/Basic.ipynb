# %%
print('Hello')
# Out:
# Hello

# %% [markdown]
# For dummies

# %%
2+2
3*3
# Out:
# 9

# %%
print(2+2)
3+3 #calk
# Out:
# 4
# 6

# %%
# %timeit [i**2 for i in range (1000)]
# Out:
# 972 µs ± 76.5 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
salary = 100000

# %%
print('salary')
# Out:
# salary

# %%
salary
# Out:
# 100000

# %%
salary * 2
# Out:
# 200000

# %%
"salary "
# Out:
# 'salary '

# %%
base_salary = 100000
bonus_rate = .10

# %%
salary = 100

# %%
type(salary)
# Out:
# int

# %%
name = 'dude'

# %%
type(name)
# Out:
# str

# %%
sex = True

# %%
type(sex)
# Out:
# bool

# %%
'hello ' + 'dude'
# Out:
# 'hello dude'

# %%
'hello'.capitalize()
# Out:
# 'Hello'

# %%
'Hello'.lower
# Out:
# <function str.lower()>

# %%
'Hello'.lower()
# Out:
# 'hello'

# %%
pay = 101

# %%
# pay = float(101)

# %%
# str(help)

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
my_list = ['Lera', 'Andrew']

# %%
my_list
# Out:
# ['Lera', 'Andrew']

# %%
my_list.append('Bob')

# %%
my_list
# Out:
# ['Lera', 'Andrew', 'Bob']

# %%
my_list.remove('Bob')

# %%
my_list
# Out:
# ['Lera', 'Andrew']

# %%
len('hello')
# Out:
# 5

# %%
len(my_list)
# Out:
# 2

# %%
second_list = ['1','2']

# %%
total = my_list + second_list

# %%
total
# Out:
# ['Lera', 'Andrew', '1', '2']

# %%
total.remove('1')

# %%
total
# Out:
# ['Lera', 'Andrew', '2']

# %%
total[0:1]
# Out:
# ['Lera']

# %%
total[0:]
# Out:
# ['Lera', 'Andrew', '2']

# %%
# Define data science job roles and required skills
job_roles = [
    {'role': 'Data Analyst', 'skills': ['Python', 'SQL', 'Excel']},
    {'role': 'Data Scientist', 'skills': ['Python', 'R', 'Machine Learning', 'Deep Learning']},
    {'role': 'Machine Learning Engineer', 'skills': ['Python', 'TensorFlow', 'PyTorch', 'Scikit-Learn']},
    {'role': 'Data Engineer', 'skills': ['Python', 'Apache Spark', 'Hadoop', 'SQL']},
    {'role': 'Business Intelligence Analyst', 'skills': ['Python', 'SQL', 'Tableau', 'Power BI', 'Excel']},
    {'role': 'Quantitative Analyst', 'skills': ['R', 'Python', 'MATLAB', 'Statistics']},
    {'role': 'Operations Analyst', 'skills': ['Python', 'SQL', 'Data Visualization', 'Process Improvement']},
    {'role': 'Database Administrator', 'skills': ['SQL', 'Oracle', 'MySQL', 'Database Management']},
    {'role': 'AI Engineer', 'skills': ['Python', 'TensorFlow', 'PyTorch', 'Computer Vision']},
    {'role': 'Statistician', 'skills': ['R', 'SAS', 'Python', 'Statistical Modeling']}
]

# %%
my_skills = ['Python', 'SQL', 'Excel']

# %%
for job in job_roles:
  print (job['skills'])
# Out:
# ['Python', 'SQL', 'Excel']
# ['Python', 'R', 'Machine Learning', 'Deep Learning']
# ['Python', 'TensorFlow', 'PyTorch', 'Scikit-Learn']
# ['Python', 'Apache Spark', 'Hadoop', 'SQL']
# ['Python', 'SQL', 'Tableau', 'Power BI', 'Excel']
# ['R', 'Python', 'MATLAB', 'Statistics']
# ['Python', 'SQL', 'Data Visualization', 'Process Improvement']
# ['SQL', 'Oracle', 'MySQL', 'Database Management']
# ['Python', 'TensorFlow', 'PyTorch', 'Computer Vision']
# ['R', 'SAS', 'Python', 'Statistical Modeling']

# %%
job_roles
# Out:
# [{'role': 'Data Analyst', 'skills': ['Python', 'SQL', 'Excel']},
#  {'role': 'Data Scientist',
#   'skills': ['Python', 'R', 'Machine Learning', 'Deep Learning']},
#  {'role': 'Machine Learning Engineer',
#   'skills': ['Python', 'TensorFlow', 'PyTorch', 'Scikit-Learn']},
#  {'role': 'Data Engineer',
#   'skills': ['Python', 'Apache Spark', 'Hadoop', 'SQL']},
#  {'role': 'Business Intelligence Analyst',
#   'skills': ['Python', 'SQL', 'Tableau', 'Power BI', 'Excel']},
#  {'role': 'Quantitative Analyst',
#   'skills': ['R', 'Python', 'MATLAB', 'Statistics']},
#  {'role': 'Operations Analyst',
#   'skills': ['Python', 'SQL', 'Data Visualization', 'Process Improvement']},
#  {'role': 'Database Administrator',
#   'skills': ['SQL', 'Oracle', 'MySQL', 'Database Management']},
#  {'role': 'AI Engineer',
#   'skills': ['Python', 'TensorFlow', 'PyTorch', 'Computer Vision']},
#  {'role': 'Statistician',
#   'skills': ['R', 'SAS', 'Python', 'Statistical Modeling']}]

# %%
import random

# List of 25 names
names = ["Alice", "Bob", "Charlie", "David", "Eve", "Frank", "Grace", "Hannah", "Ivy", "Jack",
         "Kara", "Leo", "Mia", "Nina", "Oscar", "Paul", "Quinn", "Rose", "Sam", "Tina",
         "Uma", "Vince", "Wendy", "Xander", "Yara"]

# Generate a dictionary with names as keys and random years of experience as values
years_experience = {name: random.randint(1, 40) for name in names}

print(years_experience)
# Out:
# {'Alice': 27, 'Bob': 31, 'Charlie': 28, 'David': 31, 'Eve': 39, 'Frank': 23, 'Grace': 13, 'Hannah': 37, 'Ivy': 12, 'Jack': 9, 'Kara': 25, 'Leo': 37, 'Mia': 21, 'Nina': 2, 'Oscar': 39, 'Paul': 13, 'Quinn': 11, 'Rose': 31, 'Sam': 36, 'Tina': 30, 'Uma': 23, 'Vince': 35, 'Wendy': 37, 'Xander': 30, 'Yara': 35}

# %%
years_experience
# Out:
# {'Alice': 27,
#  'Bob': 31,
#  'Charlie': 28,
#  'David': 31,
#  'Eve': 39,
#  'Frank': 23,
#  'Grace': 13,
#  'Hannah': 37,
#  'Ivy': 12,
#  'Jack': 9,
#  'Kara': 25,
#  'Leo': 37,
#  'Mia': 21,
#  'Nina': 2,
#  'Oscar': 39,
#  'Paul': 13,
#  'Quinn': 11,
#  'Rose': 31,
#  'Sam': 36,
#  'Tina': 30,
#  'Uma': 23,
#  'Vince': 35,
#  'Wendy': 37,
#  'Xander': 30,
#  'Yara': 35}

# %%
for key, value in years_experience.items():
  if value > 5:
  print (key, value)
# Out:
#   File "<ipython-input-46-2c7e488783bc>", line 3
#     print (key, value)
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
years_experience

# %%
for person, key in years_experience.items():
    if key > 5:
        print(key)

# %%
range(100)

# %%
print(range(100))

# %%
for dodo in range(100):
  print(dodo)

# %%
for dodo in range(100):
  print(dodo)

# %%
for dodo in range(100):
  if dodo <= 10:
    print(dodo);

# %%
for dodo in range(100):
  if dodo <= 10:
    print(dodo);

# %%
for dodo in range(100):
  if dodo <= 10:
    print(dodo);
  elif dodo > 10 and dodo < 20:
    print(dodo, ' much higher than expected, but ok')

# %%
for dodo in range(100):
  if dodo <= 10:
    print(dodo);
  elif dodo > 10 and dodo < 20:
    print(dodo, ' much higher than expected, but ok')

# %%
for dodo in range(100):
  if dodo <= 10:
    print(dodo, ' perfect');
  elif dodo > 10 and dodo < 20:
    print(dodo, ' much higher than expected, but ok');
  else:
    print(dodo, 'bad');

# %%
years.experience

# %%
years_experience

# %%
candidates = years_experience

# %%
candidates

# %%
del years_experience

# %%
candidates

# %%
for good_fit in candidates:
  print(good_fit);

# %%
for good_fit in candidates.items

# %%
for name, exp in candidates.items():
  if exp > 30:
    print (name, exp, ' perfect fit');
  elif exp < 30 and exp > 10:
    print (name, exp, ' its okay');
  else:
    print (name, exp, ' dont hire');

# %%
candidates.items

# %%
candidates

# %%
candidates_list = list(candidates.items())

# %%
candidates_list

# %%
candidates_list[-1]

# %%
job_roles = [
    {'role': 'Data Analyst', 'skills': ['Python', 'SQL', 'Excel']},
    {'role': 'Data Scientist', 'skills': ['Python', 'R', 'Machine Learning', 'Deep Learning']},
    {'role': 'Machine Learning Engineer', 'skills': ['Python', 'TensorFlow', 'PyTorch', 'Scikit-Learn']},
    {'role': 'Data Engineer', 'skills': ['Python', 'Apache Spark', 'Hadoop', 'SQL']},
    {'role': 'Business Intelligence Analyst', 'skills': ['Python', 'SQL', 'Tableau', 'Power BI', 'Excel']},
    {'role': 'Quantitative Analyst', 'skills': ['R', 'Python', 'MATLAB', 'Statistics']},
    {'role': 'Operations Analyst', 'skills': ['Python', 'SQL', 'Data Visualization', 'Process Improvement']},
    {'role': 'Database Administrator', 'skills': ['SQL', 'Oracle', 'MySQL', 'Database Management']},
    {'role': 'AI Engineer', 'skills': ['Python', 'TensorFlow', 'PyTorch', 'Computer Vision']},
    {'role': 'Statistician', 'skills': ['R', 'SAS', 'Python', 'Statistical Modeling']}
]
# My skills
my_skills = ['Python', 'SQL', 'Excel']

# %%
qualified_roles = []

for Int in job_roles:
  qualified = False

  for skill in my_skills:
    if skill in Int['skills']:
      qualified = True

    break
    if qualified:
      qualified_roles.append(job['role'])

    print(qualified_roles)

# %%
type(qualified_roles)

# %%
qualified_roles

# %%
skill_list

# %%
my_skills

# %%
range(0,3)

# %%
print(range(0:3))

# %%
for my in range(0,3):
  print(my)

# %%
import my_module

my_module.skill_lit

# %%
def skill(skill_name):
  return f'{skill_name} is my favorite skill'

# %%
def add_numbers(a, b):
    result = a + b
    return result

# %%
add_numbers(1,3)

# %%
def cocunut(c, d):
  total = c + d*2
  return total

# %%
cocunut

# %%
cocunut(1,2)

# %%
age = 10
name = 'Bob'

cool = f'my name is {name} and im {age} years old'
print(cool)

# %%
def introduce(name, age):
    return f'My name is {name} and I am {age} years old'

# %%
introduce('Alice', 10)

# %%
def (product, price):

# %%
def (product, price):

# %%
def sale (base_price, discount):
  final_price = base_price - discount
  return f'The total of your order is: {final_price} CAD'

# %%
sale

# %%
sale(100,20)

# %%
import my_module

# %%
my_module.sale(100,20)

# %%
import my_module

my_module.sale(130,10)

# %%
my_module

# %%
help(my_module)

# %%
help(my_module)

# %%
import my_module
help(my_module)

# %%
money = [100, 200, 400, 500]

# %%
type(money)

# %%
money

# %%
def income(dol):
  if dol > 300:
    print (f'a lot of money: CAD {dol}')
  else:
    print (f'not enought money: CAD {dol}. Min amount left:', 300 - dol)

# %%
income(100)

# %%
from module1 import income

# %%
income(200)

# %%
data_science_jobs = [
    {'job_title': 'Data Scientist', 'job_skills': "['Python', 'SQL', 'Machine Learning']", 'job_date': '2023-05-12'},
    {'job_title': 'Machine Learning Engineer', 'job_skills': "['Python', 'TensorFlow', 'Deep Learning']", 'job_date': '2023-05-15'},
    {'job_title': 'Data Analyst', 'job_skills': "['SQL', 'R', 'Tableau']", 'job_date': '2023-05-10'},
    {'job_title': 'Business Intelligence Developer', 'job_skills': "['SQL', 'PowerBI', 'Data Warehousing']", 'job_date': '2023-05-08'},
    {'job_title': 'Data Engineer', 'job_skills': "['Python', 'Spark', 'Hadoop']", 'job_date': '2023-05-18'},
    {'job_title': 'AI Specialist', 'job_skills': "['Python', 'PyTorch', 'AI Ethics']", 'job_date': '2023-05-20'}
]

# %%
from datetime import datetime

# %%
datetime.now(
)

# %%
test_date = (data_science_jobs[0]['job_date'])

# %%
print(datetime.strptime(test_date, '%Y-%m-%d'))

# %%
for job in data_science_jobs:
  job['job_date'] = datetime.strptime(job['job_date'], '%Y-%m-%d')

# %%
data_science_jobs

# %%
file = open('sample_data/california_housing_test.csv')

content = file.read()

file.close()

# %%
import pandas as pd

# %%
contents = pd.read_csv('sample_data/california_housing_test.csv')

contents['median_house_value'].sum()

# %%
# !pip install pandas

# %%
# !pip list

# %%
# !pip install pyjokes

# %%
import pyjokes as joke

# %%
joke.get_joke()

# %%
list_try = ()

# %%
list_try

# %%
list_try.add("Hello")

# %%
class LukesList:
    def __init__(self):
        """Initialize an empty list."""
        self._items = []

    def add(self, item):
        """Add an item to the end of the list."""
        self._items.append(item)

    def __getitem__(self, index):
        """Retrieve an item by index."""
        return self._items[index]

    def __setitem__(self, index, value):
        """Set an item at a specific index."""
        self._items[index] = value

    def __repr__(self):
        """Return a string representation of the list."""
        return str(self._items)

    def __len__(self):
        """Return the length of the list."""
        return len(self._items)

# %%
LukesList

# %%
LukesList.add("canada", 1)

# %%
my_list = LukesList

# %%
my_list.add(1,2)

# %%
BaseSalary(100000)

# %%
x = 100000

f'{x:,.1f}'

# %%
! pip install datasets

# %%
from datasets import load_dataset

# %%
dataset = load_dataset('lukebarousse/data_jobs')

# %%
dataset

# %%
dataset['train']

# %%
df = dataset['train'].to_pandas()

# %%
df

# %%
df['job_title']

# %%
df.info()

# %%
import pandas as pd

# %%
df.iloc[90:100]

# %%
df.info()

# %%
df.describe()

# %%
df[(df.job_title_short == 'Data Analyst') & (df.salary_year_avg > 100000)]

# %%
import pandas as pd

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-00cf07b74dcd> in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
# !pip install datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.1/316.1 kB 17.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 12.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.6.1
# ...

# %%
from datasets import load_dataset

# %%
import matplotlib.pyplot as plt

# %%
dataset = load_dataset('lukebarousse/data_jobs')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %%
df = dataset['train'].to_pandas()

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
plt.plot(df.job_posted_date, df.job_posted_date)

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df.job_title_short.value_counts()
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
date_counts = df.job_posted_date.value_counts()
date_counts = date_counts.sort_index()

# %%
date_counts
# Out:
# job_posted_date
# 2023-12-08 07:24:37    10
# 2023-01-08 00:19:57    10
# 2023-09-17 00:28:49    10
# 2023-09-07 00:07:24    10
# 2023-07-22 07:25:54    10
#                        ..
# 2023-05-17 17:27:41     1
# 2023-05-28 17:51:07     1
# 2023-09-05 17:10:27     1
# 2023-09-02 17:02:18     1
# 2023-03-12 06:32:36     1
# Name: count, Length: 607192, dtype: int64

# %%
date_counts.values
# Out:
# array([10, 10, 10, ...,  1,  1,  1])

# %%
dplt.plot(date_counts, date_counts)

# %%
df['job_posted_month'] = df ['job_posted_date'].dt.month

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
type(df.job_posted_month)
# Out:
# pandas.core.series.Series

# %%
monthly_counts = df.job_posted_month.value_counts()

# %%
monthly_counts
# Out:
# job_posted_date
# 2023-12-08 07:24:37    10
# 2023-01-08 00:19:57    10
# 2023-09-17 00:28:49    10
# 2023-09-07 00:07:24    10
# 2023-07-22 07:25:54    10
#                        ..
# 2023-05-17 17:27:41     1
# 2023-05-28 17:51:07     1
# 2023-09-05 17:10:27     1
# 2023-09-02 17:02:18     1
# 2023-03-12 06:32:36     1
# Name: count, Length: 607192, dtype: int64

# %%
monthly_counts = monthly_counts.sort_index()

# %%
monthly_counts
# Out:
# job_posted_month
# 1     91822
# 2     64578
# 3     64084
# 4     62919
# 5     52104
# 6     61572
# 7     63777
# 8     75162
# 9     62359
# 10    66611
# 11    64450
# 12    56303
# Name: count, dtype: int64

# %%
plt.plot(monthly_counts.index, monthly_counts)

# %%
job_counts = df.job_title_short.value_counts()

# %%
job_counts.sort_values(ascending = True, inplace = True)
plt.barh(job_counts.index, job_counts)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
months = ['January', 'February', 'March', 'April']
postings = [120, 150, 100, 130]

# %%
plt.plot(months, postings)

# %%
months = ['January', 'February', 'March', 'April']
postings = [120, 150, 100, 130]

# %%
plt.bar(months, postings)
# Out:
# <BarContainer object of 4 artists>

# %%
job_counts.sort_values(ascending = True, inplace = True)
plt.title('Graf')
plt.ylabel('Name')
plt.xlabel('Num of postings')
plt.barh(job_counts.index, job_counts)
# Out:
# <BarContainer object of 10 artists>

# %%
countries = df.job_country
countries
# Out:
# 0         United States
# 1                Mexico
# 2               Germany
# 3         United States
# 4                 Sudan
#               ...
# 785736        Singapore
# 785737          Germany
# 785738         Malaysia
# 785739            Sudan
# 785740            India
# Name: job_country, Length: 785741, dtype: object

# %%
num_of_postings = df.job_country.value_counts(ascending=False).head(5)
num_of_postings
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
# Name: count, dtype: int64

# %%
plt.bar(num_of_postings.index, num_of_postings.values, color = 'orange')
# Out:
# <BarContainer object of 5 artists>

# %%
avg_salary = df.salary_year_avg.sort_values(ascending = False)
avg_salary
# Out:
# 554784    960000.0
# 665811    890000.0
# 168402    650000.0
# 387378    585000.0
# 160521    550000.0
#             ...
# 785736         NaN
# 785737         NaN
# 785738         NaN
# 785739         NaN
# 785740         NaN
# Name: salary_year_avg, Length: 785741, dtype: float64

# %%
df.job_title_short
# Out:
# 0         Senior Data Engineer
# 1                 Data Analyst
# 2                Data Engineer
# 3                Data Engineer
# 4                Data Engineer
#                   ...
# 785736       Software Engineer
# 785737            Data Analyst
# 785738        Business Analyst
# 785739           Data Engineer
# 785740       Software Engineer
# Name: job_title_short, Length: 785741, dtype: object

# %%
plt.barh(df.job_title_short, df.salary_year_avg)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-122-ac4d3e7c6c41> in <cell line: 1>()
# ----> 1 plt.barh(df.job_title_short, df.salary_year_avg)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in barh(y, width, height, left, align, data, **kwargs)
#    2455         y, width, height=0.8, left=None, *, align='center',
#    2456         data=None, **kwargs):
# -> 2457     return gca().barh(
#    2458         y, width, height=height, left=left, align=align,
#    2459         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in barh(self, y, width, height, left, align, data, **kwargs)
#    2647         """
#    2648         kwargs.setdefault('orientation', 'horizontal')
# -> 2649         patches = self.bar(x=left, height=height, width=width, bottom=y,
# ...

# %%
df.groupby('job_title_short')['salary_year_avg'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8d31c99f4a98> in <cell line: 1>()
# ----> 1 df.groupby('job_title_short')['salary_year_avg'].mean()
#
# NameError: name 'df' is not defined

# %%
# !pip install datasets
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
# Data Cleanup (not needed for all problems but good to do anyways)
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.1/316.1 kB 21.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 15.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 16.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.6.1
# ...

# %%
job_salary = df.groupby('job_title_short')['salary_year_avg'].mean()
job_salary
# Out:
# job_title_short
# Business Analyst              91082.612833
# Cloud Engineer               111268.453846
# Data Analyst                  93841.907854
# Data Engineer                130125.604250
# Data Scientist               135988.837171
# Machine Learning Engineer    126774.315972
# Senior Data Analyst          113911.363665
# Senior Data Engineer         145840.611624
# Senior Data Scientist        154206.292996
# Software Engineer            113393.760054
# Name: salary_year_avg, dtype: float64

# %%
job_salary.sort_values(ascending = True, inplace = True)

# %%
job_salary
# Out:
# job_title_short
# Senior Data Scientist        154206.292996
# Senior Data Engineer         145840.611624
# Data Scientist               135988.837171
# Data Engineer                130125.604250
# Machine Learning Engineer    126774.315972
# Senior Data Analyst          113911.363665
# Software Engineer            113393.760054
# Cloud Engineer               111268.453846
# Data Analyst                  93841.907854
# Business Analyst              91082.612833
# Name: salary_year_avg, dtype: float64

# %%
plt.barh(job_salary.index, job_salary)
# Out:
# <BarContainer object of 10 artists>

# %%
df['month'] = df.job_posted_date.dt.month

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
month_pay_avg = df.groupby('month')['salary_year_avg'].mean()

# %%
month_pay_avg
# Out:
# month
# 1     123007.422072
# 2     122913.927237
# 3     122947.810047
# 4     121856.551050
# 5     123656.747729
# 6     124321.135360
# 7     123470.572994
# 8     125819.429100
# 9     125222.984594
# 10    124606.653605
# 11    119817.184014
# 12    120199.423414
# Name: salary_year_avg, dtype: float64

# %%
plt.plot(month_pay_avg.index, month_pay_avg, color = 'red')
plt.title('Trend')
plt.xlabel('Month Number')
plt.ylabel('Annual pay')
# Out:
# Text(0, 0.5, 'Annual pay')

# %%
plt.bar(num_of_postings.index, num_of_postings.values, color = 'orange')
plt.title('Number of Jobs per Country')
plt.xlabel('Country')
plt.xticks(rotation=45, ha = 'right')
plt.ylabel('Number of Postings')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ee9a0d27a7c2> in <cell line: 1>()
# ----> 1 plt.bar(num_of_postings.index, num_of_postings.values, color = 'orange')
#       2 plt.title('Number of Jobs per Country')
#       3 plt.xlabel('Country')
#       4 plt.xticks(rotation=45, ha = 'right')
#       5 plt.ylabel('Number of Postings')
#
# NameError: name 'num_of_postings' is not defined

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
group = df.groupby('job_title_short')['salary_rate']
group

# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

job_salary = df.groupby('job_title_short')['salary_year_avg'].mean()
job_salary = job_salary.sort_values(ascending=True)

plt.barh(job_salary.index, job_salary.values)
plt.title('Average Salary by Job Title')
plt.xlabel('Average Salary')
plt.show()

# %%
dfjob_country
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-39762d48485b> in <cell line: 1>()
# ----> 1 df['job_country']
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/displayhook.py in __call__(self, result)
#     260             self.start_displayhook()
#     261             self.write_output_prompt()
# --> 262             format_dict, md_dict = self.compute_format_data(result)
#     263             self.update_user_ns(result)
#     264             self.fill_exec_result(result)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/displayhook.py in compute_format_data(self, result)
#     149
#     150         """
# --> 151         return self.shell.display_formatter.format(result)
#     152
#     153     # This can be set to True by the write_output_prompt method in a subclass
#
# ...

# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

df['job_posted_month'] = df['job_posted_date'].dt.month
monthly_avg_salary = df.groupby('job_posted_month')['salary_year_avg'].mean().sort_index()


plt.title('Average Salary by Job Month')
plt.xlabel('Month')
plt.ylabel('Average Salary')
plt.plot(monthly_avg_salary.index, monthly_avg_salary.values, color='red', label='Average Salary')
plt.legend()
plt.show()

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

df['job_posted_month'] = df['job_posted_date'].dt.month
monthly_avg_salary = df.groupby('job_posted_month')['salary_year_avg'].mean().sort_index()

plt.plot(monthly_avg_salary.index, monthly_avg_salary.values, color='green', label='Average Salary')
plt.show()

# %%
job_counts.plot(kind= 'bar'/)
# Out:
# <Axes: xlabel='job_title_short'>

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
top_platform = df.job_via.value_counts()
top_platform = top_platform.sort_values(ascending=False).head(5)

# %%
top_platform
# Out:
# job_via
# via LinkedIn       186679
# via BeBee          103507
# via Trabajo.org     61562
# via Indeed          42756
# via Recruit.net     23646
# Name: count, dtype: int64

# %%
plt.barh(top_platform.index, top_platform, color = 'Green')
# Out:
# <BarContainer object of 5 artists>

# %%
top_platform.plot(kind = 'bar')
# Out:
# <Axes: xlabel='job_via'>

# %%
monthly_job_counts = df.job_posted_date.dt.month.value_counts()
monthly_job_counts.sort_index(ascending = True, inplace = True)

# %%
monthly_job_counts.plot(kind = 'line', color = 'Red')
plt.xlabel('Month')
plt.ylabel('Number of Job Postings')
plt.title('Trend of Job Postings Over Time')
# Out:
# Text(0.5, 1.0, 'Trend of Job Postings Over Time')

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
top_job_location = df.job_location.value_counts(ascending=False).head(6)

# %%
top_job_location = top_job_location.drop('Anywhere')

# %%
top_job_location
# Out:
# job_location
# Singapore                      23415
# Paris, France                  12311
# Bengaluru, Karnataka, India    11474
# London, UK                     10564
# Madrid, Spain                   9787
# Name: count, dtype: int64

# %%
top_job_location.plot(kind = 'barh')
plt.xlabel('Count of Jobs')
plt.ylabel('Job Location')
plt.title('Number of Job Postings by Job Location')
# Out:
# Text(0.5, 1.0, 'Number of Job Postings by Job Location')

# %%
df.salary_year_avg.sort_values(ascending=False).head(5)
# Out:
# 554784    960000.0
# 665811    890000.0
# 168402    650000.0
# 387378    585000.0
# 160521    550000.0
# Name: salary_year_avg, dtype: float64

# %%
median_salary = df.groupby('job_title_short')['salary_year_avg'].mean()

# %%
median_salary.sort_values(ascending=True, inplace = True)

# %%
median_salary
# Out:
# job_title_short
# Senior Data Scientist        154206.292996
# Senior Data Engineer         145840.611624
# Data Scientist               135988.837171
# Data Engineer                130125.604250
# Machine Learning Engineer    126774.315972
# Senior Data Analyst          113911.363665
# Software Engineer            113393.760054
# Cloud Engineer               111268.453846
# Data Analyst                  93841.907854
# Business Analyst              91082.612833
# Name: salary_year_avg, dtype: float64

# %%
median_salary.plot(kind = 'barh')
plt.xlabel('Salary($USD)')
plt.ylabel('')
plt.title('Median Salary by Job Title')
# Out:
# Text(0.5, 1.0, 'Median Salary by Job Title')
