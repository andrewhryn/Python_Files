# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(5)
# Out:
#              job_title_short  \
# 189738  Senior Data Engineer
# 441205         Data Engineer
# 748348        Data Scientist
# 745774      Business Analyst
# 237839          Data Analyst
#
#                                                 job_title      job_location  \
# 189738  AIML - Sr Data Engineer, Siri Search - Data an...       Seattle, WA
# 441205               Data Security Partner in Engineering  Belgrade, Serbia
# 748348                                  Data Scientist II          Anywhere
# 745774  Supply Chain Analyst with focus on demand plan...  Hadsten, Denmark
# 237839                               Data Analyst (m/w/d)   Vienna, Austria
#
#                      job_via job_schedule_type  job_work_from_home  \
# 189738       via SimplyHired         Full-time               False
# 441205  via Jobs Trabajo.org         Full-time               False
# 748348          via LinkedIn         Full-time                True
# 745774       via Trabajo.org         Full-time               False
# 237839          via LinkedIn         Full-time               False
#
#        search_location     job_posted_date  job_no_degree_mention  \
# 189738         Georgia 2023-10-07 15:50:39                  False
# 441205          Serbia 2023-03-20 16:40:56                   True
# 748348           Sudan 2023-01-20 21:43:21                  False
# 745774         Denmark 2023-04-12 20:49:08                   True
# 237839         Austria 2023-04-19 07:24:23                   True
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 189738                  True  United States        None              NaN
# 441205                 False         Serbia        None              NaN
# 748348                  True          Sudan        year         140000.0
# 745774                 False        Denmark        None              NaN
# 237839                 False        Austria        None              NaN
#
#         salary_hour_avg         company_name  \
# 189738              NaN                Apple
# 441205              NaN  Robert Bosch d.o.o.
# 748348              NaN    Medical Solutions
# 745774              NaN        Hoyer Denmark
# 237839              NaN  MARESI Austria GmbH
#
#                                                job_skills  \
# 189738  ['java', 'scala', 'python', 'go', 'sql', 'hado...
# 441205                                               None
# 748348  ['sql', 'python', 'r', 'scala', 'c', 'sql serv...
# 745774                                          ['excel']
# 237839                     ['sharepoint', 'excel', 'sap']
#
#                                           job_type_skills
# 189738  {'libraries': ['hadoop', 'spark', 'kafka'], 'p...
# 441205                                               None
# 748348  {'async': ['jira'], 'cloud': ['azure', 'databr...
# 745774                       {'analyst_tools': ['excel']}
# 237839  {'analyst_tools': ['sharepoint', 'excel', 'sap']}

# %%
df.index.name = 'job_index'

# %%
df.head
# Out:
# <bound method NDFrame.head of                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 1                  Data Analyst
# 2                 Data Engineer
# 3                 Data Engineer
# 4                 Data Engineer
# ...                         ...
# 785736        Software Engineer
# 785737             Data Analyst
# 785738         Business Analyst
# 785739            Data Engineer
# 785740        Software Engineer
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 1                                               Data Analyst
# 2          Data Engineer/Scientist/Analyst, Mid or Senior...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                     Data Engineer- Sr Jobs
# ...                                                      ...
# 785736                                       DevOps Engineer
# 785737                                      CRM Data Analyst
# 785738                        Commercial Analyst - Start Now
# 785739     Principal Associate, Data Engineer (Remote-Eli...
# 785740                                    AWS System Analyst
#
#                                   job_location                    job_via  \
# job_index
# 0                                Watertown, CT            via Work Nearby
# 1                 Guadalajara, Jalisco, Mexico           via BeBee México
# 2                              Berlin, Germany               via LinkedIn
# 3                              San Antonio, TX          via Diversity.com
# 4                               Washington, DC         via Clearance Jobs
# ...                                        ...                        ...
# 785736                               Singapura        melalui Trabajo.org
# 785737                      Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                                Malaysia           melalui Ricebowl
# 785739     Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                   India             melalui Trigyn
#
#           job_schedule_type  job_work_from_home       search_location  \
# job_index
# 0                 Full-time               False  Texas, United States
# 1                 Full-time               False                Mexico
# 2                 Full-time               False               Germany
# 3                 Full-time               False  Texas, United States
# 4                 Full-time               False                 Sudan
# ...                     ...                 ...                   ...
# 785736      Pekerjaan tetap               False             Singapore
# 785737      Pekerjaan tetap               False               Germany
# 785738      Pekerjaan tetap               False              Malaysia
# 785739      Pekerjaan tetap               False                 Sudan
# 785740      Pekerjaan tetap               False                 India
#
#               job_posted_date  job_no_degree_mention  job_health_insurance  \
# job_index
# 0         2023-06-16 13:44:15                  False                 False
# 1         2023-01-14 13:18:07                  False                 False
# 2         2023-10-10 13:14:55                  False                 False
# 3         2023-07-04 13:01:41                   True                 False
# 4         2023-08-07 14:29:36                  False                 False
# ...                       ...                    ...                   ...
# 785736    2023-03-13 06:16:16                  False                 False
# 785737    2023-03-12 06:18:18                  False                 False
# 785738    2023-03-12 06:32:36                  False                 False
# 785739    2023-03-12 06:32:15                  False                 False
# 785740    2023-03-13 06:16:31                  False                 False
#
#              job_country salary_rate  salary_year_avg  salary_hour_avg  \
# job_index
# 0          United States        None              NaN              NaN
# 1                 Mexico        None              NaN              NaN
# 2                Germany        None              NaN              NaN
# 3          United States        None              NaN              NaN
# 4                  Sudan        None              NaN              NaN
# ...                  ...         ...              ...              ...
# 785736         Singapore        None              NaN              NaN
# 785737           Germany        None              NaN              NaN
# 785738          Malaysia        None              NaN              NaN
# 785739             Sudan        None              NaN              NaN
# 785740             India        None              NaN              NaN
#
#                                  company_name  \
# job_index
# 0                        Boehringer Ingelheim
# 1                  Hewlett Packard Enterprise
# 2                    ALPHA Augmented Services
# 3                Southwest Research Institute
# 4                             Kristina Daniel
# ...                                       ...
# 785736     CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                       HABA FAMILYGROUP
# 785738                  Lendlease Corporation
# 785739                            Capital One
# 785740                                 Trigyn
#
#                                                   job_skills  \
# job_index
# 0                                                       None
# 1          ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2          ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3          ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4          ['bash', 'python', 'oracle', 'aws', 'ansible',...
# ...                                                      ...
# 785736     ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                        ['sas', 'sas', 'sql', 'excel']
# 785738                               ['powerpoint', 'excel']
# 785739     ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                       ['aws', 'flow']
#
#                                              job_type_skills
# job_index
# 0                                                       None
# 1          {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2          {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3          {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4          {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                                                      ...
# 785736     {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737     {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738            {'analyst_tools': ['powerpoint', 'excel']}
# 785739     {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740                 {'cloud': ['aws'], 'other': ['flow']}
#
# [785741 rows x 17 columns]>

# %%
df.index.dtype
# Out:
# dtype('int64')

# %%
type(df.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
df_usa = df[df['job_country'] == 'United States']

# %%
df_usa
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
# ...                         ...
# 785673           Data Scientist
# 785685             Data Analyst
# 785692           Data Scientist
# 785703             Data Analyst
# 785705             Data Analyst
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5                                          GCP Data Engineer
# 6                          Senior Data Engineer  - GCP Cloud
# 9                                          Data Scientist II
# ...                                                      ...
# 785673                       Asset Management Data Scientist
# 785685                                          Data Analyst
# 785692                  Data Scientist- Hybrid Work Location
# 785703               Data Analyst - CRYPTOGRAPHY - Full-time
# 785705             Expert Business Data Analyst - Now Hiring
#
#                job_location            job_via         job_schedule_type  \
# job_index
# 0             Watertown, CT    via Work Nearby                 Full-time
# 3           San Antonio, TX  via Diversity.com                 Full-time
# 5                  Anywhere   via ZipRecruiter  Contractor and Temp work
# 6              Dearborn, MI       via LinkedIn                 Full-time
# 9                  Anywhere   via ZipRecruiter                 Full-time
# ...                     ...                ...                       ...
# 785673         New York, NY    via Trabajo.org                 Full-time
# 785685     Indianapolis, IN    via Trabajo.org                 Full-time
# 785692           Dayton, OH    via Ai-Jobs.net                 Full-time
# 785703             Anywhere       via Snagajob                 Full-time
# 785705          Oakland, CA       via Snagajob                 Full-time
#
#            job_work_from_home            search_location     job_posted_date  \
# job_index
# 0                       False       Texas, United States 2023-06-16 13:44:15
# 3                       False       Texas, United States 2023-07-04 13:01:41
# 5                        True                    Georgia 2023-11-07 14:01:59
# 6                       False     Florida, United States 2023-03-27 13:18:18
# 9                        True    New York, United States 2023-04-23 13:02:57
# ...                       ...                        ...                 ...
# 785673                  False    New York, United States 2023-10-16 06:01:53
# 785685                  False    Illinois, United States 2023-07-16 06:01:27
# 785692                  False    Illinois, United States 2023-04-21 06:02:31
# 785703                   True       Texas, United States 2023-01-28 06:02:55
# 785705                  False  California, United States 2023-01-09 06:00:25
#
#            job_no_degree_mention  job_health_insurance    job_country  \
# job_index
# 0                          False                 False  United States
# 3                           True                 False  United States
# 5                          False                 False  United States
# 6                          False                 False  United States
# 9                          False                 False  United States
# ...                          ...                   ...            ...
# 785673                      True                 False  United States
# 785685                      True                 False  United States
# 785692                     False                  True  United States
# 785703                      True                 False  United States
# 785705                     False                 False  United States
#
#           salary_rate  salary_year_avg  salary_hour_avg  \
# job_index
# 0                None              NaN              NaN
# 3                None              NaN              NaN
# 5                None              NaN              NaN
# 6                None              NaN              NaN
# 9                None              NaN              NaN
# ...               ...              ...              ...
# 785673           None              NaN              NaN
# 785685           None              NaN              NaN
# 785692           year         157500.0              NaN
# 785703           None              NaN              NaN
# 785705           None              NaN              NaN
#
#                             company_name  \
# job_index
# 0                   Boehringer Ingelheim
# 3           Southwest Research Institute
# 5                        smart folks inc
# 6          Miracle Software Systems, Inc
# 9             Radwell International, LLC
# ...                                  ...
# 785673              JPMorgan Chase & Co.
# 785685            Aara Technologies, Inc
# 785692                            Tenet3
# 785703       Axelon Services Corporation
# 785705                  PG&E Corporation
#
#                                                   job_skills  \
# job_index
# 0                                                       None
# 3          ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 5                                   ['python', 'sql', 'gcp']
# 6          ['sql', 'python', 'java', 'sql server', 'gcp',...
# 9          ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
# ...                                                      ...
# 785673                                                  None
# 785685                                      ['sql', 'excel']
# 785692                             ['python', 'matlab', 'r']
# 785703                                                  None
# 785705                          ['sql', 'python', 'tableau']
#
#                                              job_type_skills
# job_index
# 0                                                       None
# 3          {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 5          {'cloud': ['gcp'], 'programming': ['python', '...
# 6          {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 9          {'analyst_tools': ['excel'], 'cloud': ['azure'...
# ...                                                      ...
# 785673                                                  None
# 785685     {'analyst_tools': ['excel'], 'programming': ['...
# 785692            {'programming': ['python', 'matlab', 'r']}
# 785703                                                  None
# 785705     {'analyst_tools': ['tableau'], 'programming': ...
#
# [206292 rows x 17 columns]

# %%
df_usa.reset_index(inplace = True)

# %%
df_usa.index.name = 'new_index'

# %%
df_usa
# Out:
#            job_index       job_title_short  \
# new_index
# 0                  0  Senior Data Engineer
# 1                  3         Data Engineer
# 2                  5         Data Engineer
# 3                  6  Senior Data Engineer
# 4                  9        Data Scientist
# ...              ...                   ...
# 206287        785673        Data Scientist
# 206288        785685          Data Analyst
# 206289        785692        Data Scientist
# 206290        785703          Data Analyst
# 206291        785705          Data Analyst
#
#                                                    job_title  \
# new_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 1          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 2                                          GCP Data Engineer
# 3                          Senior Data Engineer  - GCP Cloud
# 4                                          Data Scientist II
# ...                                                      ...
# 206287                       Asset Management Data Scientist
# 206288                                          Data Analyst
# 206289                  Data Scientist- Hybrid Work Location
# 206290               Data Analyst - CRYPTOGRAPHY - Full-time
# 206291             Expert Business Data Analyst - Now Hiring
#
#                job_location            job_via         job_schedule_type  \
# new_index
# 0             Watertown, CT    via Work Nearby                 Full-time
# 1           San Antonio, TX  via Diversity.com                 Full-time
# 2                  Anywhere   via ZipRecruiter  Contractor and Temp work
# 3              Dearborn, MI       via LinkedIn                 Full-time
# 4                  Anywhere   via ZipRecruiter                 Full-time
# ...                     ...                ...                       ...
# 206287         New York, NY    via Trabajo.org                 Full-time
# 206288     Indianapolis, IN    via Trabajo.org                 Full-time
# 206289           Dayton, OH    via Ai-Jobs.net                 Full-time
# 206290             Anywhere       via Snagajob                 Full-time
# 206291          Oakland, CA       via Snagajob                 Full-time
#
#            job_work_from_home            search_location     job_posted_date  \
# new_index
# 0                       False       Texas, United States 2023-06-16 13:44:15
# 1                       False       Texas, United States 2023-07-04 13:01:41
# 2                        True                    Georgia 2023-11-07 14:01:59
# 3                       False     Florida, United States 2023-03-27 13:18:18
# 4                        True    New York, United States 2023-04-23 13:02:57
# ...                       ...                        ...                 ...
# 206287                  False    New York, United States 2023-10-16 06:01:53
# 206288                  False    Illinois, United States 2023-07-16 06:01:27
# 206289                  False    Illinois, United States 2023-04-21 06:02:31
# 206290                   True       Texas, United States 2023-01-28 06:02:55
# 206291                  False  California, United States 2023-01-09 06:00:25
#
#            job_no_degree_mention  job_health_insurance    job_country  \
# new_index
# 0                          False                 False  United States
# 1                           True                 False  United States
# 2                          False                 False  United States
# 3                          False                 False  United States
# 4                          False                 False  United States
# ...                          ...                   ...            ...
# 206287                      True                 False  United States
# 206288                      True                 False  United States
# 206289                     False                  True  United States
# 206290                      True                 False  United States
# 206291                     False                 False  United States
#
#           salary_rate  salary_year_avg  salary_hour_avg  \
# new_index
# 0                None              NaN              NaN
# 1                None              NaN              NaN
# 2                None              NaN              NaN
# 3                None              NaN              NaN
# 4                None              NaN              NaN
# ...               ...              ...              ...
# 206287           None              NaN              NaN
# 206288           None              NaN              NaN
# 206289           year         157500.0              NaN
# 206290           None              NaN              NaN
# 206291           None              NaN              NaN
#
#                             company_name  \
# new_index
# 0                   Boehringer Ingelheim
# 1           Southwest Research Institute
# 2                        smart folks inc
# 3          Miracle Software Systems, Inc
# 4             Radwell International, LLC
# ...                                  ...
# 206287              JPMorgan Chase & Co.
# 206288            Aara Technologies, Inc
# 206289                            Tenet3
# 206290       Axelon Services Corporation
# 206291                  PG&E Corporation
#
#                                                   job_skills  \
# new_index
# 0                                                       None
# 1          ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 2                                   ['python', 'sql', 'gcp']
# 3          ['sql', 'python', 'java', 'sql server', 'gcp',...
# 4          ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
# ...                                                      ...
# 206287                                                  None
# 206288                                      ['sql', 'excel']
# 206289                             ['python', 'matlab', 'r']
# 206290                                                  None
# 206291                          ['sql', 'python', 'tableau']
#
#                                              job_type_skills
# new_index
# 0                                                       None
# 1          {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 2          {'cloud': ['gcp'], 'programming': ['python', '...
# 3          {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 4          {'analyst_tools': ['excel'], 'cloud': ['azure'...
# ...                                                      ...
# 206287                                                  None
# 206288     {'analyst_tools': ['excel'], 'programming': ['...
# 206289            {'programming': ['python', 'matlab', 'r']}
# 206290                                                  None
# 206291     {'analyst_tools': ['tableau'], 'programming': ...
#
# [206292 rows x 18 columns]

# %%
df_usa.set_index('job_index', inplace = True)

# %%
df_usa
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
# ...                         ...
# 785673           Data Scientist
# 785685             Data Analyst
# 785692           Data Scientist
# 785703             Data Analyst
# 785705             Data Analyst
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5                                          GCP Data Engineer
# 6                          Senior Data Engineer  - GCP Cloud
# 9                                          Data Scientist II
# ...                                                      ...
# 785673                       Asset Management Data Scientist
# 785685                                          Data Analyst
# 785692                  Data Scientist- Hybrid Work Location
# 785703               Data Analyst - CRYPTOGRAPHY - Full-time
# 785705             Expert Business Data Analyst - Now Hiring
#
#                job_location            job_via         job_schedule_type  \
# job_index
# 0             Watertown, CT    via Work Nearby                 Full-time
# 3           San Antonio, TX  via Diversity.com                 Full-time
# 5                  Anywhere   via ZipRecruiter  Contractor and Temp work
# 6              Dearborn, MI       via LinkedIn                 Full-time
# 9                  Anywhere   via ZipRecruiter                 Full-time
# ...                     ...                ...                       ...
# 785673         New York, NY    via Trabajo.org                 Full-time
# 785685     Indianapolis, IN    via Trabajo.org                 Full-time
# 785692           Dayton, OH    via Ai-Jobs.net                 Full-time
# 785703             Anywhere       via Snagajob                 Full-time
# 785705          Oakland, CA       via Snagajob                 Full-time
#
#            job_work_from_home            search_location     job_posted_date  \
# job_index
# 0                       False       Texas, United States 2023-06-16 13:44:15
# 3                       False       Texas, United States 2023-07-04 13:01:41
# 5                        True                    Georgia 2023-11-07 14:01:59
# 6                       False     Florida, United States 2023-03-27 13:18:18
# 9                        True    New York, United States 2023-04-23 13:02:57
# ...                       ...                        ...                 ...
# 785673                  False    New York, United States 2023-10-16 06:01:53
# 785685                  False    Illinois, United States 2023-07-16 06:01:27
# 785692                  False    Illinois, United States 2023-04-21 06:02:31
# 785703                   True       Texas, United States 2023-01-28 06:02:55
# 785705                  False  California, United States 2023-01-09 06:00:25
#
#            job_no_degree_mention  job_health_insurance    job_country  \
# job_index
# 0                          False                 False  United States
# 3                           True                 False  United States
# 5                          False                 False  United States
# 6                          False                 False  United States
# 9                          False                 False  United States
# ...                          ...                   ...            ...
# 785673                      True                 False  United States
# 785685                      True                 False  United States
# 785692                     False                  True  United States
# 785703                      True                 False  United States
# 785705                     False                 False  United States
#
#           salary_rate  salary_year_avg  salary_hour_avg  \
# job_index
# 0                None              NaN              NaN
# 3                None              NaN              NaN
# 5                None              NaN              NaN
# 6                None              NaN              NaN
# 9                None              NaN              NaN
# ...               ...              ...              ...
# 785673           None              NaN              NaN
# 785685           None              NaN              NaN
# 785692           year         157500.0              NaN
# 785703           None              NaN              NaN
# 785705           None              NaN              NaN
#
#                             company_name  \
# job_index
# 0                   Boehringer Ingelheim
# 3           Southwest Research Institute
# 5                        smart folks inc
# 6          Miracle Software Systems, Inc
# 9             Radwell International, LLC
# ...                                  ...
# 785673              JPMorgan Chase & Co.
# 785685            Aara Technologies, Inc
# 785692                            Tenet3
# 785703       Axelon Services Corporation
# 785705                  PG&E Corporation
#
#                                                   job_skills  \
# job_index
# 0                                                       None
# 3          ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 5                                   ['python', 'sql', 'gcp']
# 6          ['sql', 'python', 'java', 'sql server', 'gcp',...
# 9          ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
# ...                                                      ...
# 785673                                                  None
# 785685                                      ['sql', 'excel']
# 785692                             ['python', 'matlab', 'r']
# 785703                                                  None
# 785705                          ['sql', 'python', 'tableau']
#
#                                              job_type_skills
# job_index
# 0                                                       None
# 3          {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 5          {'cloud': ['gcp'], 'programming': ['python', '...
# 6          {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 9          {'analyst_tools': ['excel'], 'cloud': ['azure'...
# ...                                                      ...
# 785673                                                  None
# 785685     {'analyst_tools': ['excel'], 'programming': ['...
# 785692            {'programming': ['python', 'matlab', 'r']}
# 785703                                                  None
# 785705     {'analyst_tools': ['tableau'], 'programming': ...
#
# [206292 rows x 17 columns]

# %%
df.set_index('job_posted_date', inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/jq/9vrfyvt57yv6zsk7ddnttm3h0000gn/T/ipykernel_16175/3216481388.py in ?()
# ----> 1 df.set_index('job_posted_date', inplace=True)
#       2 df.head()
#
# /opt/anaconda3/envs/luke_course/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['job_posted_date'] are in the columns"

# %%
df.head()
# Out:
#                           job_title_short  \
# job_posted_date
# 2023-06-16 13:44:15  Senior Data Engineer
# 2023-01-14 13:18:07          Data Analyst
# 2023-10-10 13:14:55         Data Engineer
# 2023-07-04 13:01:41         Data Engineer
# 2023-08-07 14:29:36         Data Engineer
#
#                                                              job_title  \
# job_posted_date
# 2023-06-16 13:44:15  Senior Clinical Data Engineer / Principal Clin...
# 2023-01-14 13:18:07                                       Data Analyst
# 2023-10-10 13:14:55  Data Engineer/Scientist/Analyst, Mid or Senior...
# 2023-07-04 13:01:41  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 2023-08-07 14:29:36                             Data Engineer- Sr Jobs
#
#                                      job_location             job_via  \
# job_posted_date
# 2023-06-16 13:44:15                 Watertown, CT     via Work Nearby
# 2023-01-14 13:18:07  Guadalajara, Jalisco, Mexico    via BeBee México
# 2023-10-10 13:14:55               Berlin, Germany        via LinkedIn
# 2023-07-04 13:01:41               San Antonio, TX   via Diversity.com
# 2023-08-07 14:29:36                Washington, DC  via Clearance Jobs
#
#                     job_schedule_type  job_work_from_home  \
# job_posted_date
# 2023-06-16 13:44:15         Full-time               False
# 2023-01-14 13:18:07         Full-time               False
# 2023-10-10 13:14:55         Full-time               False
# 2023-07-04 13:01:41         Full-time               False
# 2023-08-07 14:29:36         Full-time               False
#
#                           search_location  job_no_degree_mention  \
# job_posted_date
# 2023-06-16 13:44:15  Texas, United States                  False
# 2023-01-14 13:18:07                Mexico                  False
# 2023-10-10 13:14:55               Germany                  False
# 2023-07-04 13:01:41  Texas, United States                   True
# 2023-08-07 14:29:36                 Sudan                  False
#
#                      job_health_insurance    job_country salary_rate  \
# job_posted_date
# 2023-06-16 13:44:15                 False  United States        None
# 2023-01-14 13:18:07                 False         Mexico        None
# 2023-10-10 13:14:55                 False        Germany        None
# 2023-07-04 13:01:41                 False  United States        None
# 2023-08-07 14:29:36                 False          Sudan        None
#
#                      salary_year_avg  salary_hour_avg  \
# job_posted_date
# 2023-06-16 13:44:15              NaN              NaN
# 2023-01-14 13:18:07              NaN              NaN
# 2023-10-10 13:14:55              NaN              NaN
# 2023-07-04 13:01:41              NaN              NaN
# 2023-08-07 14:29:36              NaN              NaN
#
#                                      company_name  \
# job_posted_date
# 2023-06-16 13:44:15          Boehringer Ingelheim
# 2023-01-14 13:18:07    Hewlett Packard Enterprise
# 2023-10-10 13:14:55      ALPHA Augmented Services
# 2023-07-04 13:01:41  Southwest Research Institute
# 2023-08-07 14:29:36               Kristina Daniel
#
#                                                             job_skills  \
# job_posted_date
# 2023-06-16 13:44:15                                               None
# 2023-01-14 13:18:07  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2023-10-10 13:14:55  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 2023-07-04 13:01:41  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 2023-08-07 14:29:36  ['bash', 'python', 'oracle', 'aws', 'ansible',...
#
#                                                        job_type_skills
# job_posted_date
# 2023-06-16 13:44:15                                               None
# 2023-01-14 13:18:07  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2023-10-10 13:14:55  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 2023-07-04 13:01:41  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 2023-08-07 14:29:36  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...

# %%
df.reset_index(drop= True, inplace=True)

# %%
df
# Out:
#            job_posted_date       job_title_short  \
# 0      2023-06-16 13:44:15  Senior Data Engineer
# 1      2023-01-14 13:18:07          Data Analyst
# 2      2023-10-10 13:14:55         Data Engineer
# 3      2023-07-04 13:01:41         Data Engineer
# 4      2023-08-07 14:29:36         Data Engineer
# ...                    ...                   ...
# 785736 2023-03-13 06:16:16     Software Engineer
# 785737 2023-03-12 06:18:18          Data Analyst
# 785738 2023-03-12 06:32:36      Business Analyst
# 785739 2023-03-12 06:32:15         Data Engineer
# 785740 2023-03-13 06:16:31     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785740                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 0                             Watertown, CT            via Work Nearby
# 1              Guadalajara, Jalisco, Mexico           via BeBee México
# 2                           Berlin, Germany               via LinkedIn
# 3                           San Antonio, TX          via Diversity.com
# 4                            Washington, DC         via Clearance Jobs
# ...                                     ...                        ...
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home       search_location  \
# 0              Full-time               False  Texas, United States
# 1              Full-time               False                Mexico
# 2              Full-time               False               Germany
# 3              Full-time               False  Texas, United States
# 4              Full-time               False                 Sudan
# ...                  ...                 ...                   ...
# 785736   Pekerjaan tetap               False             Singapore
# 785737   Pekerjaan tetap               False               Germany
# 785738   Pekerjaan tetap               False              Malaysia
# 785739   Pekerjaan tetap               False                 Sudan
# 785740   Pekerjaan tetap               False                 India
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 0                       False                 False  United States
# 1                       False                 False         Mexico
# 2                       False                 False        Germany
# 3                        True                 False  United States
# 4                       False                 False          Sudan
# ...                       ...                   ...            ...
# 785736                  False                 False      Singapore
# 785737                  False                 False        Germany
# 785738                  False                 False       Malaysia
# 785739                  False                 False          Sudan
# 785740                  False                 False          India
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 0             None              NaN              NaN
# 1             None              NaN              NaN
# 2             None              NaN              NaN
# 3             None              NaN              NaN
# 4             None              NaN              NaN
# ...            ...              ...              ...
# 785736        None              NaN              NaN
# 785737        None              NaN              NaN
# 785738        None              NaN              NaN
# 785739        None              NaN              NaN
# 785740        None              NaN              NaN
#
#                               company_name  \
# 0                     Boehringer Ingelheim
# 1               Hewlett Packard Enterprise
# 2                 ALPHA Augmented Services
# 3             Southwest Research Institute
# 4                          Kristina Daniel
# ...                                    ...
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 0                                                    None
# 1       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2       ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4       ['bash', 'python', 'oracle', 'aws', 'ansible',...
# ...                                                   ...
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills
# 0                                                    None
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                                                   ...
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740              {'cloud': ['aws'], 'other': ['flow']}
#
# [785741 rows x 17 columns]

# %%
df.pivot_table(
    index='company_name',
    values='salary_year_avg',
    aggfunc='median'
).sort_index(ascending=False)
# Out:
#                                     salary_year_avg
# company_name
# ​Illinois State Board of Education     62536.000000
# Технологическая компания              280000.000000
# ЛАНИТ                                 400000.000000
# ztp                                    95000.000000
# zooplus SE                            161750.000000
# ...                                             ...
# 1 Point System LLC.                   170000.000000
# 1 Point System                        137290.484375
# 0nward Select                          92500.000000
# /dev/color                            125000.000000
# #twiceasnice Recruiting                65000.000000
#
# [7316 rows x 1 columns]

# %%
pivot_sample = df.pivot_table(
    index='job_title_short',
    values='salary_year_avg',
    aggfunc='median'
)
pivot_sample.reset_index(inplace=True)

pivot_sample.set_index('salary_year_avg', inplace=True)

pivot_sample
# Out:
#                            job_title_short
# salary_year_avg
# 85000.0                   Business Analyst
# 90000.0                     Cloud Engineer
# 90000.0                       Data Analyst
# 125000.0                     Data Engineer
# 127500.0                    Data Scientist
# 106415.0         Machine Learning Engineer
# 111175.0               Senior Data Analyst
# 147500.0              Senior Data Engineer
# 155500.0             Senior Data Scientist
# 99150.0                  Software Engineer
