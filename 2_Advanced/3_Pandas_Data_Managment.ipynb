# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()

# %%
df_original.sample(10)
# Out:
#           job_title_short                                          job_title  \
# 537444      Data Engineer                           Data Engineer Databricks
# 361791       Data Analyst                                       Data Analyst
# 468658       Data Analyst                             Sales and Data Analyst
# 476941       Data Analyst                                       Data Analyst
# 97285    Business Analyst                                   Business Analyst
# 106296      Data Engineer                                      Data Engineer
# 349609       Data Analyst       Data Analyst/ Utrecht - Room for Advancement
# 236718       Data Analyst                                Junior Data Analyst
# 278127       Data Analyst                                       Data Analyst
# 6634    Software Engineer  Associate System Support Engineer - (For Gazip...
#
#                   job_location              job_via job_schedule_type  \
# ...

# %%
df_alter = df_original

# %%
#bad because id are same, so df are same

id(df_original) == id(df_alter)
# Out:
# True

# %%
# we will use .copy method

df_alter = df_original.copy

# %%
id(df_original) == id(df_alter)
# Out:
# False

# %%
id(df_original)
# Out:
# 6026904656

# %%
 id(df_alter)
# Out:
# 6027169408

# %%
df_original['salary_year_avg']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 785736   NaN
# 785737   NaN
# 785738   NaN
# 785739   NaN
# 785740   NaN
# Name: salary_year_avg, Length: 785741, dtype: float64

# %%
df_cleaned = df_original.copy()

# %%
df_clear = df_cleaned.dropna(subset = ['salary_year_avg'])

# %%
df_clear.head()
# Out:
#     job_title_short                                job_title  \
# 28   Data Scientist                      CRM Data Specialist
# 77    Data Engineer                            Data Engineer
# 92    Data Engineer  Remote - Data Engineer - Permanent - W2
# 100  Data Scientist  Data Scientist, Risk Data Mining - USDS
# 109    Data Analyst    Senior Supply Chain Analytics Analyst
#
#                                 job_location          job_via  \
# 28   San José Province, San José, Costa Rica  via Ai-Jobs.net
# 77                             Arlington, VA     via LinkedIn
# 92                                  Anywhere     via LinkedIn
# 100                        Mountain View, CA     via LinkedIn
# 109                                 Anywhere       via Get.It
#
#     job_schedule_type  job_work_from_home            search_location  \
# 28          Full-time               False                 Costa Rica
# 77          Full-time               False                      Sudan
# ...

# %%
df_original.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
len(df_original)
# Out:
# 785741

# %%
len(df_clear)
# Out:
# 22003

# %%
df_random = df_original.copy()

# %%
df_random.sample(10)
# Out:
#                   job_title_short  \
# 777843              Data Engineer
# 174166               Data Analyst
# 512764             Data Scientist
# 114866              Data Engineer
# 544767               Data Analyst
# 2909    Machine Learning Engineer
# 620998        Senior Data Analyst
# 759848               Data Analyst
# 748442               Data Analyst
# 518741             Data Scientist
#
#                                                 job_title  \
# 777843                                      Data Engineer
# 174166    Bloomberg Data, Syndicated Loans Analyst, Seoul
# 512764                                   Data Scientist 1
# 114866                         Intermediate Data Engineer
# 544767                                       Data Analyst
# 2909               Data Science/Machine Learning Engineer
# 620998                        Senior Finance Data Analyst
# 759848                  BI/Data Analyst Jobs in Abu Dhabi
# ...

# %%
df_random.sample(frac = 0.1)
# Out:
#               job_title_short  \
# 253973         Data Scientist
# 468690           Data Analyst
# 394903    Senior Data Analyst
# 259040         Data Scientist
# 55679   Senior Data Scientist
# ...                       ...
# 692325           Data Analyst
# 430082           Data Analyst
# 581305      Software Engineer
# 142308           Data Analyst
# 143874  Senior Data Scientist
#
#                                                 job_title     job_location  \
# 253973                                     Data Scientist     New York, NY
# 468690              Responsable del equipo Data Analytics            Spain
# 394903        Senior Healthcare Data Analyst - Now Hiring      Waltham, MA
# 259040  Clinical Data Scientist, Clinical Data Managem...       Street, UK
# 55679                           Senior Big Data Developer           Mexico
# ...                                                   ...              ...
# ...

# %%
len(df_original) * 0.1
# Out:
# 78574.1

# %%
df_missing = df_original.copy()

# %%
id(df_original)
# Out:
# 6026904656

# %%
id(df_missing)
# Out:
# 5886148944

# %%
df_original['salary_year_avg'].median
# Out:
# <bound method Series.median of 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 785736   NaN
# 785737   NaN
# 785738   NaN
# 785739   NaN
# 785740   NaN
# Name: salary_year_avg, Length: 785741, dtype: float64>

# %%
median_year = df_missing['salary_year_avg'].median()

# %%
median_year
# Out:
# 115000.0

# %%
df_missing['salary_year_avg'] = df_missing['salary_year_avg'].fillna(value= median_year)

# %%
df_missing['salary_year_avg'].head(5)
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# Name: salary_year_avg, dtype: float64
