# %%
# Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df = df[df['job_title_short']=='Data Analyst']

# %%
df_exploded = df.explode('job_skills')

skill_stats = df_exploded.groupby('job_skills').agg(
    skill_count=('job_skills', 'count'),
    median_salary=('salary_year_avg', 'median')
)
skill_stats = skill_stats.sort_values(by='skill_count', ascending=False).head(10)

# %%
skill_stats.plot(kind='scatter', x='skill_count', y='median_salary')
plt.tight_layout()
plt.show
plt.xlabel('Count of Job Postings')
plt.ylabel('Median Yearly Salary')
plt.title('Salary vs. Count of Job Postings for Top 10 Skills')
# Out:
# Text(0.5, 1.0, 'Salary vs. Count of Job Postings for Top 10 Skills')

# %%
df
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 31        Data Analyst                           Stage - Data Analyst F/H
# 34        Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...                ...                                                ...
# 785703    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst          Expert Business Data Analyst - Now Hiring
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                         job_location  \
# 1       Guadalajara, Jalisco, Mexico
# ...

# %%
num_of_postings = df.groupby('job_title_short').agg(
    num_of_jobs = ('job_title_short', 'count'),
    median_salary = ('salary_year_avg', 'median')
).dropna()
num_of_postings
# Out:
#                            num_of_jobs  median_salary
# job_title_short
# Business Analyst                 49063        85000.0
# Cloud Engineer                   12331        90000.0
# Data Analyst                    196075        90000.0
# Data Engineer                   186241       125000.0
# Data Scientist                  172286       127500.0
# Machine Learning Engineer        14080       106415.0
# Senior Data Analyst              29216       111175.0
# Senior Data Engineer             44563       147500.0
# Senior Data Scientist            36957       155500.0
# Software Engineer                44929        99150.0

# %%
num_of_postings.plot(kind='scatter', x='num_of_jobs', y='median_salary')
# Out:
# <Axes: xlabel='num_of_jobs', ylabel='median_salary'>

# %%
num_of_postings
# Out:
#                            num_of_jobs  median_salary
# job_title_short
# Business Analyst                 49063        85000.0
# Cloud Engineer                   12331        90000.0
# Data Analyst                    196075        90000.0
# Data Engineer                   186241       125000.0
# Data Scientist                  172286       127500.0
# Machine Learning Engineer        14080       106415.0
# Senior Data Analyst              29216       111175.0
# Senior Data Engineer             44563       147500.0
# Senior Data Scientist            36957       155500.0
# Software Engineer                44929        99150.0

# %%
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
num_of_postings_county = df.groupby('job_country').agg(
    num_of_jobs = ('job_title_short', 'count'),
    median_salary = ('salary_year_avg', 'median')
).dropna().sort_values('num_of_jobs',ascending=False).head(7)
num_of_postings_county
# Out:
#                 num_of_jobs  median_salary
# job_country
# United States        206292       119187.5
# India                 51088       111175.0
# United Kingdom        40375       104668.0
# France                39922        97444.0
# Germany               27694       111175.0
# Spain                 25100        98391.5
# Singapore             23696       100500.0

# %%
num_of_postings_county.plot(kind='scatter', x='num_of_jobs', y='median_salary')
plt.xlabel('Number of Job Postings')
plt.ylabel('Median Salary in USD')
plt.title('Job postings with salary in Top 7 Countries')
# Out:
# Text(0.5, 1.0, 'Job postings with salary in Top 7 Countries')

# %%
# Out:
#                 num_of_jobs  median_salary
# job_country
# United States        206292       119187.5
# India                 51088       111175.0
# United Kingdom        40375       104668.0
# France                39922        97444.0
# Germany               27694       111175.0
# Spain                 25100        98391.5
# Singapore             23696       100500.0

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...
